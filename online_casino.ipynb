# %% [markdown]
# # 1. Exploratory data analysis

# %% [markdown]
# ## Goals
# - Be in a data-driven mindset
# - Train my data-analysis skills
# - Develop a modelling strategy
#
#
# ## Basic Analysis
# ### Dataset description
# - **target variable** : "moderator" column (if a moderator played the round)
# - **lines and columns** : 55 575 rows x 10 columns
# - **data types** : 6 continuous values, 1 discrete value (bool), 1 date and 1 id like style
# - **missing values** : 10 missing rows for col "time", mainly when there is no player in the room.
#
# Column "ID" will likely be ignored for the rest of the analysis.
#
# ### In-depth analysis

# %% [markdown]
# ## Librairies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Dataset

# %%
casino_df = pd.read_csv('onlineCasino.csv', parse_dates=['time'])
casino_df
# Out:
#             ID  gamers  skins      money  ticks   peopleWin  peopleLost  \
# 0      2091103     144    174  283.57000  14.30  125.459984    0.250000
# 1      2091104     134    182  279.30000   1.14    5.810003  177.040000
# 2      2091105     139    179  282.87000   3.91  125.010000    5.960000
# 3      2091106     139    169  271.44000   1.15    6.900001  181.850000
# 4      2091107     142    177  304.88000   1.00    0.000000  304.880000
# ...        ...     ...    ...        ...    ...         ...         ...
# 55570  2146673     114    146  246.68002   1.74   46.410004   36.400000
# 55571  2146674     106    131  190.87997   2.35   49.629974   14.489999
# 55572  2146675     110    138  209.81992   1.40   23.020000   76.109985
# 55573  2146676     101    128  165.06999   5.76   56.540000    1.790000
# 55574  2146677     109    143  197.73000   1.66   40.779995   35.780000
#
#            outpay                time  moderator
# 0      408.780000 2021-08-25 16:43:00      False
# 1      108.070010 2021-08-25 16:44:00      False
# 2      401.919920 2021-08-25 16:44:00      False
# 3       96.490005 2021-08-25 16:45:00      False
# 4        0.000000 2021-08-25 16:45:00      False
# ...           ...                 ...        ...
# 55570  226.020020 2021-09-14 22:01:00      False
# 55571  156.730010 2021-09-14 22:02:00      False
# 55572  219.819980 2021-09-14 22:02:00      False
# 55573  202.730030 2021-09-14 22:03:00      False
# 55574  263.909900 2021-09-14 22:03:00      False
#
# [55575 rows x 10 columns]

# %%
casino_df.dtypes.value_counts()
# Out:
# float64           5
# int64             3
# datetime64[ns]    1
# bool              1
# dtype: int64

# %% [markdown]
# ## Missing values

# %%
casino_df.isna().sum()
# Out:
# ID             0
# gamers         0
# skins          0
# money          0
# ticks          0
# peopleWin      0
# peopleLost     0
# outpay         0
# time          10
# moderator      0
# dtype: int64

# %%
casino_df[casino_df['time'].isna()]
# Out:
#             ID  gamers  skins      money  ticks  peopleWin  peopleLost  \
# 5522   2096625       0      0   0.000000   2.85   0.000000        0.00
# 5864   2096967       0      0   0.000000  23.89   0.000000        0.00
# 6762   2097865       0      0   0.000000   1.17   0.000000        0.00
# 7155   2098258       0      0   0.000000   5.62   0.000000        0.00
# 8005   2099108       0      0   0.000000   1.08   0.000000        0.00
# 8006   2099109       0      0   0.000000  10.19   0.000000        0.00
# 8186   2099289       0      0   0.000000  26.78   0.000000        0.00
# 12920  2104023      38     46  70.470010   8.08  25.929998        0.00
# 18782  2109885      26     31  55.059994   1.10   0.900000       39.98
# 45427  2136530       3      6   7.500000   1.57   1.710000        0.00
#
#        outpay time  moderator
# 5522      0.0  NaT      False
# 5864      0.0  NaT      False
# 6762      0.0  NaT      False
# 7155      0.0  NaT      False
# 8005      0.0  NaT      False
# 8006      0.0  NaT      False
# 8186      0.0  NaT      False
# 12920     0.0  NaT      False
# 18782     0.0  NaT      False
# 45427     0.0  NaT      False

# %% [markdown]
# ## Numerical analysis

# %%
casino_df.describe()
# Out:
#                  ID        gamers         skins         money         ticks  \
# count  5.557500e+04  55575.000000  55575.000000  55575.000000  55575.000000
# mean   2.118890e+06    123.028754    158.333495    285.020029     12.031466
# std    1.604326e+04     26.145191     30.969729    195.503233    240.496913
# min    2.091103e+06      0.000000      0.000000      0.000000      1.000000
# 25%    2.104996e+06    102.000000    135.000000    215.475005      1.300000
# 50%    2.118890e+06    121.000000    155.000000    255.010030      1.950000
# 75%    2.132784e+06    137.000000    175.000000    308.409940      3.890000
# max    2.146677e+06    491.000000    552.000000   5696.327000  23522.650000
#
#           peopleWin    peopleLost        outpay
# count  55575.000000  55575.000000  55575.000000
# mean      66.642813     79.308366    272.350410
# std      116.713177    186.749071    221.625618
# min        0.000000      0.000000      0.000000
# 25%       19.780007      3.150000    158.399975
# 50%       58.359997     30.670000    266.610050
# 75%       97.999977    111.685007    361.935070
# max    21681.592000   5696.327000  25943.201000

# %%
def plot_violon(x, hue):
    plt.fig

# %%
px.violin(casino_df,
    x='money',
    color='moderator',
    box=True,
    points='all')

# %%
px.violin(casino_df,
    x='skins',
    color='moderator',
    box=True,
    points='all')

# %% [markdown]
# ## Feature engineering

# %%
outcome_df = casino_df.copy()
outcome_df['main_outcome'] = casino_df['peopleWin'] > casino_df['peopleLost']
outcome_df
# Out:
#             ID  gamers  skins      money  ticks   peopleWin  peopleLost  \
# 0      2091103     144    174  283.57000  14.30  125.459984    0.250000
# 1      2091104     134    182  279.30000   1.14    5.810003  177.040000
# 2      2091105     139    179  282.87000   3.91  125.010000    5.960000
# 3      2091106     139    169  271.44000   1.15    6.900001  181.850000
# 4      2091107     142    177  304.88000   1.00    0.000000  304.880000
# ...        ...     ...    ...        ...    ...         ...         ...
# 55570  2146673     114    146  246.68002   1.74   46.410004   36.400000
# 55571  2146674     106    131  190.87997   2.35   49.629974   14.489999
# 55572  2146675     110    138  209.81992   1.40   23.020000   76.109985
# 55573  2146676     101    128  165.06999   5.76   56.540000    1.790000
# 55574  2146677     109    143  197.73000   1.66   40.779995   35.780000
#
#            outpay                time  moderator  main_outcome
# 0      408.780000 2021-08-25 16:43:00      False          True
# 1      108.070010 2021-08-25 16:44:00      False         False
# 2      401.919920 2021-08-25 16:44:00      False          True
# 3       96.490005 2021-08-25 16:45:00      False         False
# 4        0.000000 2021-08-25 16:45:00      False         False
# ...           ...                 ...        ...           ...
# 55570  226.020020 2021-09-14 22:01:00      False          True
# 55571  156.730010 2021-09-14 22:02:00      False          True
# 55572  219.819980 2021-09-14 22:02:00      False         False
# 55573  202.730030 2021-09-14 22:03:00      False          True
# 55574  263.909900 2021-09-14 22:03:00      False          True
#
# [55575 rows x 11 columns]
